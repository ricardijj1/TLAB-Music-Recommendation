# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/Users/sa21/Desktop/TLAB-Music-Recommendation/Data/raw/train.csv")
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'sadness', 'feelings', 'topic', 'age'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# sadness                     0
# feelings                    0
# topic                       0
# age                         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28362 non-null  int64
#  1   artist_name               28362 non-null  object
#  2   track_name                28362 non-null  object
#  3   release_date              28362 non-null  int64
#  4   genre                     28362 non-null  object
#  5   lyrics                    28362 non-null  object
#  6   len                       28362 non-null  int64
#  7   dating                    28362 non-null  float64
#  8   violence                  28362 non-null  float64
#  9   world/life                28362 non-null  float64
#  10  night/time                28362 non-null  float64
#  11  shake the audience        28362 non-null  float64
#  12  family/gospel             28362 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'sadness', 'feelings', 'topic', 'age'],
#       dtype='object')

# %%
# Drop categorical and non-numeric features for modeling
df_cleaned = df.drop(columns=['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'lyrics', 'topic', 'genre'])

# %%
df_cleaned
# Out:
#        len    dating  violence  world/life  night/time  shake the audience  \
# 0       95  0.000598  0.063746    0.000598    0.000598            0.000598
# 1       51  0.035537  0.096777    0.443435    0.001284            0.001284
# 2       24  0.002770  0.002770    0.002770    0.002770            0.002770
# 3       54  0.048249  0.001548    0.001548    0.001548            0.021500
# 4       48  0.001350  0.001350    0.417772    0.001350            0.001350
# ...    ...       ...       ...         ...         ...                 ...
# 28357   78  0.001350  0.001350    0.001350    0.001350            0.001350
# 28358   67  0.001284  0.001284    0.035338    0.001284            0.001284
# 28359   77  0.001504  0.154302    0.168988    0.001504            0.039755
# 28360   67  0.001196  0.001196    0.001196    0.001196            0.048359
# 28361   83  0.001012  0.075202    0.001012    0.001012            0.001012
#
#        family/gospel  romantic  communication   obscene     music  \
# ...

# %%
#save cvs

df_cleaned.to_csv("/Users/sa21/Desktop/TLAB-Music-Recommendation/Data/processed/Clean_music_data.csv", index=False)
df_cleaned
# Out:
#        len    dating  violence  world/life  night/time  shake the audience  \
# 0       95  0.000598  0.063746    0.000598    0.000598            0.000598
# 1       51  0.035537  0.096777    0.443435    0.001284            0.001284
# 2       24  0.002770  0.002770    0.002770    0.002770            0.002770
# 3       54  0.048249  0.001548    0.001548    0.001548            0.021500
# 4       48  0.001350  0.001350    0.417772    0.001350            0.001350
# ...    ...       ...       ...         ...         ...                 ...
# 28357   78  0.001350  0.001350    0.001350    0.001350            0.001350
# 28358   67  0.001284  0.001284    0.035338    0.001284            0.001284
# 28359   77  0.001504  0.154302    0.168988    0.001504            0.039755
# 28360   67  0.001196  0.001196    0.001196    0.001196            0.048359
# 28361   83  0.001012  0.075202    0.001012    0.001012            0.001012
#
#        family/gospel  romantic  communication   obscene     music  \
# ...
